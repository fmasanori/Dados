# %%
import pandas as pd
import seaborn as sb
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

movie = 'movies_metadata.csv'
df = pd.read_csv(movie)

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# homepage                 7782 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# poster_path              45080 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# ...

# %%
df.sample(10)
# Out:
#        adult belongs_to_collection   budget  \
# 7240   False                   NaN        0
# 4731   False                   NaN        0
# 20006  False                   NaN  4437508
# 31698  False                   NaN        0
# 39712  False                   NaN        0
# 32005  False                   NaN        0
# 38856  False                   NaN        0
# 6953   False                   NaN        0
# 32759  False                   NaN        0
# 18125  False                   NaN        0
#
#                                                   genres  \
# 7240   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4731                 [{'id': 99, 'name': 'Documentary'}]
# 20006  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 31698  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 39712                      [{'id': 18, 'name': 'Drama'}]
# 32005                     [{'id': 35, 'name': 'Comedy'}]
# 38856                      [{'id': 18, 'name': 'Drama'}]
# ...

# %%
df.sample(10)
# Out:
#        adult                              belongs_to_collection    budget  \
# 32060  False                                                NaN         0
# 31680  False  {'id': 353325, 'name': 'Joe Dirt Collection', ...         0
# 32652  False                                                NaN         0
# 36220  False                                                NaN   6400000
# 41719  False                                                NaN         0
# 34664  False                                                NaN         0
# 36184  False                                                NaN  20000000
# 41712  False                                                NaN         0
# 7122   False                                                NaN   3000000
# 24119  False                                                NaN         0
#
#                                                   genres  \
# 32060                     [{'id': 35, 'name': 'Comedy'}]
# ...

# %%
df.sample(5)
# Out:
#        adult                              belongs_to_collection    budget  \
# 38908  False                                                NaN         0
# 1925   False                                                NaN  20000000
# 44116  False                                                NaN         0
# 6312   False                                                NaN         0
# 32897  False  {'id': 32153, 'name': 'Fallen Collection', 'po...         0
#
#                                                   genres  \
# 38908                   [{'id': 53, 'name': 'Thriller'}]
# 1925   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 44116                                                 []
# 6312   [{'id': 10749, 'name': 'Romance'}, {'id': 37, ...
# 32897  [{'id': 10770, 'name': 'TV Movie'}, {'id': 18,...
#
#                           homepage      id    imdb_id original_language  \
# 38908  http://chronicle2015.co.kr/  340746  tt4619940                ko
# ...

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.groupby('vote_count').size()
# Out:
# vote_count
# 0.0        2899
# 1.0        3264
# 2.0        3132
# 3.0        2787
# 4.0        2480
# 5.0        2097
# 6.0        1747
# 7.0        1570
# 8.0        1359
# 9.0        1194
# 10.0       1171
# 11.0        944
# 12.0        859
# 13.0        733
# 14.0        700
# 15.0        674
# 16.0        601
# 17.0        554
# 18.0        497
# 19.0        438
# 20.0        463
# 21.0        400
# 22.0        413
# 23.0        337
# 24.0        337
# 25.0        312
# 26.0        310
# 27.0        269
# 28.0        266
# 29.0        232
# 30.0        239
# 31.0        219
# 32.0        234
# 33.0        211
# 34.0        221
# 35.0        189
# 36.0        177
# 37.0        171
# 38.0        171
# 39.0        145
# 40.0        133
# 41.0        161
# 42.0        136
# 43.0        123
# 44.0        125
#            ...
# 6559.0        1
# 6595.0        1
# 6598.0        1
# 6656.0        1
# 6678.0        1
# 6734.0        1
# 6737.0        1
# 6768.0        1
# ...

# %%
df.groupby('vote_average').size().sort_values()
# Out:
# vote_average
# 9.8       1
# 0.7       1
# 9.6       1
# 1.1       1
# 9.1       3
# 9.4       3
# 1.2       4
# 9.2       4
# 1.4       5
# 1.6       6
# 8.9       7
# 1.9       8
# 1.8       9
# 1.7      13
# 1.3      13
# 0.5      13
# 2.1      16
# 9.3      18
# 9.5      18
# 2.4      19
# 2.2      20
# 8.6      25
# 1.5      30
# 2.6      31
# 8.8      32
# 2.9      40
# 2.7      44
# 8.7      45
# 2.3      45
# 3.1      49
# 8.4      51
# 2.8      68
# 3.2      71
# 3.4     100
# 1.0     105
# 8.2     110
# 3.6     111
# 2.5     123
# 2.0     124
# 8.1     132
# 3.3     154
# 3.7     154
# 9.0     159
# 8.5     162
# 8.3     169
#        ...
# 4.2     224
# 7.9     228
# 4.1     238
# 3.5     258
# 3.0     260
# 3.8     266
# 4.4     349
# 4.6     382
# 7.8     407
# 4.7     455
# 7.7     469
# 4.3     483
# 7.6     487
# 4.9     512
# 4.5     547
# 5.1     642
# 4.8     663
# 4.0     685
# 5.2     690
# 7.4     691
# 8.0     765
# 7.2     807
# 7.5     851
# 7.1     879
# ...

# %%
df.groupby('revenue').size().sort_values()
# Out:
# revenue
# 18591272.0         1
# 45833132.0         1
# 45742101.0         1
# 45735397.0         1
# 45710059.0         1
# 45681173.0         1
# 45636368.0         1
# 45610410.0         1
# 45554533.0         1
# 45479110.0         1
# 45465299.0         1
# 45858563.0         1
# 45361000.0         1
# 45236543.0         1
# 45172994.0         1
# 45056771.0         1
# 44909486.0         1
# 44907260.0         1
# 44862187.0         1
# 44806783.0         1
# 44793222.0         1
# 44785053.0         1
# 44726644.0         1
# 45284974.0         1
# 45892212.0         1
# 45916769.0         1
# 45967935.0         1
# 46652768.0         1
# 46616067.0         1
# 46546197.0         1
# 46471023.0         1
# 46442528.0         1
# 46434570.0         1
# 46405336.0         1
# 46396427.0         1
# 46357676.0         1
# 46264384.0         1
# 46243000.0         1
# 46236000.0         1
# 46221189.0         1
# 46216641.0         1
# 46201432.0         1
# 46189568.0         1
# ...

# %%
df.groupby('vote_count').size().sort_values().plot(kind='barh')

# %%
df.groupby('vote_count').size().sort_values()

# %%
df.groupby('vote_count').size().sort_values().tail(20).plot(kind='barh', figsize=(10,10))

# %%
df.groupby('vote_count').size().sort_values().tail(20).plot(kind='barh', figsize=(10,10))

# %%
df.groupby('vote_count').size().sort_values().tail(10).plot(kind='barh', figsize=(10,10))

# %%
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
df.groupby('vote_count').mean()
# Out:
#                  revenue     runtime  vote_average
# vote_count
# 0.0         1.357737e+04   76.394286      0.000000
# 1.0         1.659016e+04   83.798938      5.713388
# 2.0         7.565547e+04   85.504525      5.767178
# 3.0         3.494295e+04   89.089105      5.784248
# 4.0         1.075283e+05   90.172609      5.795887
# 5.0         1.390122e+05   90.894309      5.793562
# 6.0         1.017791e+05   91.198281      5.841843
# 7.0         1.883065e+05   91.331633      5.871783
# 8.0         1.717454e+05   94.655580      5.890581
# 9.0         2.194890e+05   94.949622      5.901591
# 10.0        3.596503e+05   96.498291      5.932963
# 11.0        2.997498e+05   94.929936      5.953919
# 12.0        4.381959e+05   95.176950      5.991735
# 13.0        4.183729e+05   95.825137      5.946385
# 14.0        6.119504e+05   96.505714      5.992571
# 15.0        7.140137e+05   98.668648      5.961276
# 16.0        2.986035e+05   98.502496      6.040765
# ...

# %%
df.rename(columns={'revenue': 'Rendimento',
                   'vote_count': 'Total de votos'
                  }, inplace=True)

# %%
df.groupby('Total de votos').mean()
# Out:
#                   Rendimento     runtime  vote_average
# Total de votos
# 0.0             1.357737e+04   76.394286      0.000000
# 1.0             1.659016e+04   83.798938      5.713388
# 2.0             7.565547e+04   85.504525      5.767178
# 3.0             3.494295e+04   89.089105      5.784248
# 4.0             1.075283e+05   90.172609      5.795887
# 5.0             1.390122e+05   90.894309      5.793562
# 6.0             1.017791e+05   91.198281      5.841843
# 7.0             1.883065e+05   91.331633      5.871783
# 8.0             1.717454e+05   94.655580      5.890581
# 9.0             2.194890e+05   94.949622      5.901591
# 10.0            3.596503e+05   96.498291      5.932963
# 11.0            2.997498e+05   94.929936      5.953919
# 12.0            4.381959e+05   95.176950      5.991735
# 13.0            4.183729e+05   95.825137      5.946385
# 14.0            6.119504e+05   96.505714      5.992571
# 15.0            7.140137e+05   98.668648      5.961276
# ...

# %%
df.groupby('title').mean()
# Out:
#                                                     Rendimento  runtime  \
# title
# !Women Art Revolution                                      0.0     83.0
# #1 Cheerleader Camp                                        0.0     95.0
# #Horror                                                    0.0     90.0
# #chicagoGirl                                               0.0     74.0
# $1,000 on the Black                                        0.0    104.0
# $100,000 for Ringo                                         0.0     98.0
# $5 a Day                                                   0.0     98.0
# $50K and a Call Girl: A Love Story                         0.0     90.0
# $9.99                                                      0.0     78.0
# $ellebrity                                                 0.0     89.0
# '49-'17                                                    0.0     61.0
# '71                                                  1625847.0     99.0
# ...

# %%
df.rename(columns={'vote_average': 'Média de votos',
                   'runtime': 'Tempo de duração',
                   'title': 'Filme'
                  }, inplace=True)

# %%
df.groupby('Filme').mean()
# Out:
#                                                     Rendimento  \
# Filme
# !Women Art Revolution                                      0.0
# #1 Cheerleader Camp                                        0.0
# #Horror                                                    0.0
# #chicagoGirl                                               0.0
# $1,000 on the Black                                        0.0
# $100,000 for Ringo                                         0.0
# $5 a Day                                                   0.0
# $50K and a Call Girl: A Love Story                         0.0
# $9.99                                                      0.0
# $ellebrity                                                 0.0
# '49-'17                                                    0.0
# '71                                                  1625847.0
# 'D'                                                        0.0
# 'Gator Bait                                                0.0
# ...

# %%
df.groupby('original_title').mean()
# Out:
#                                                Rendimento  Tempo de duração  \
# original_title
# !Women Art Revolution                                 0.0              83.0
# #1 Cheerleader Camp                                   0.0              95.0
# #Horror                                               0.0              90.0
# #Pellichoopulu                                  5500000.0             124.0
# #SELFIEPARTY                                          0.0              90.0
# #chicagoGirl                                          0.0              74.0
# $ Dollars                                             0.0             121.0
# $5 a Day                                              0.0              98.0
# $50K and a Call Girl: A Love Story                    0.0              90.0
# $9.99                                                 0.0              78.0
# $ellebrity                                            0.0              89.0
# ...

# %%
df.rename(columns={'original_title': 'Filmes',
                
                  }, inplace=True)

# %%
df.groupby('Filmes').mean()
# Out:
#                                                Rendimento  Tempo de duração  \
# Filmes
# !Women Art Revolution                                 0.0              83.0
# #1 Cheerleader Camp                                   0.0              95.0
# #Horror                                               0.0              90.0
# #Pellichoopulu                                  5500000.0             124.0
# #SELFIEPARTY                                          0.0              90.0
# #chicagoGirl                                          0.0              74.0
# $ Dollars                                             0.0             121.0
# $5 a Day                                              0.0              98.0
# $50K and a Call Girl: A Love Story                    0.0              90.0
# $9.99                                                 0.0              78.0
# $ellebrity                                            0.0              89.0
# ...

# %%
df.groupby('Filmes').size().sort_values().tail(20).plot(kind='barh', figsize=(10,10))

# %%
df.groupby('Filmes').size().sort_values().tail(20).plot(kind='barh', figsize=(10,10))

# %%
df.groupby('Média de votos').size().sort_values().tail(10).plot(kind='barh', figsize=(10,10))

# %%
df.groupby('Média de votos').size().sort_values().tail(20).plot(kind='barh', figsize=(10,10))

# %%
df.groupby(['Média de votos', 'Filmes']).size().sort_values().tail(20).plot(kind='barh', figsize=(10,10))
